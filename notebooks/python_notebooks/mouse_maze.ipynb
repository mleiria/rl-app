# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import random
from collections import deque

# %%
# --- 1. Define the DQN Agent ---

class DQNAgent:
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size

        # Hyperparameters
        self.memory = deque(maxlen=2000) # Experience Replay memory
        self.gamma = 0.95    # Discount factor for future rewards
        self.epsilon = 1.0   # Exploration rate (starts at 100%)
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        self.learning_rate = 0.001

        # The Deep Neural Network model
        self.model = self._build_model()

    def _build_model(self):
        # A simple sequential neural network
        model = nn.Sequential(
            nn.Linear(self.state_size, 24),
            nn.ReLU(),
            nn.Linear(24, 24),
            nn.ReLU(),
            nn.Linear(24, self.action_size)
        )
        return model

    def remember(self, state, action, reward, next_state, done):
        """Stores an experience in the replay memory."""
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        """Chooses an action using the Epsilon-Greedy policy."""
        # With probability epsilon, take a random action (explore)
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        
        # Otherwise, use the model to predict the best action (exploit)
        state_tensor = torch.FloatTensor(state).unsqueeze(0) # Convert state to a PyTorch tensor
        with torch.no_grad():
            act_values = self.model(state_tensor)
        return np.argmax(act_values.cpu().data.numpy())

    def replay(self, batch_size):
        """Trains the network using a random batch from the replay memory."""
        if len(self.memory) < batch_size:
            return # Don't train if memory is not full enough
        
        minibatch = random.sample(self.memory, batch_size)
        
        optimizer = optim.Adam(self.model.parameters(), lr=self.learning_rate)
        loss_fn = nn.MSELoss()

        for state, action, reward, next_state, done in minibatch:
            state_tensor = torch.FloatTensor(state).unsqueeze(0)
            next_state_tensor = torch.FloatTensor(next_state).unsqueeze(0)
            
            # The Bellman Equation: target = reward + gamma * max(Q(next_state))
            target = reward
            if not done:
                # Predict future reward with the model
                target = reward + self.gamma * torch.max(self.model(next_state_tensor)[0]).item()
            
            # Get current Q-values prediction
            current_q_values = self.model(state_tensor)
            
            # Create the target Q-values. We only update the Q-value for the action we took.
            target_q_values = current_q_values.clone()
            target_q_values[0][action] = target

            # Standard PyTorch training step
            optimizer.zero_grad()
            loss = loss_fn(current_q_values, target_q_values)
            loss.backward()
            optimizer.step()

        # Decay epsilon to reduce exploration over time
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

# %%
# Environment parameters
STATE_SIZE = 1  # The agent's position on the line
ACTION_SIZE = 2 # 0: move left, 1: move right
EPISODES = 500
BATCH_SIZE = 32

# Create our agent
agent = DQNAgent(STATE_SIZE, ACTION_SIZE)

# The simple 1D environment
line_size = 5 # A line from 0 to 4
goal_position = 4

for e in range(EPISODES):
    # Reset the environment for a new episode
    state = np.array([0]) # Start at position 0
    
    for time in range(50): # Max steps per episode
        # Agent chooses an action
        action = agent.act(state)
        
        # Environment reacts to the action
        next_state = state.copy()
        if action == 0: # Move left
            next_state[0] = max(0, state[0] - 1)
        elif action == 1: # Move right
            next_state[0] = min(line_size - 1, state[0] + 1)
            
        # Determine the reward
        done = next_state[0] == goal_position
        reward = 10 if done else -1 # Big reward for reaching goal, small penalty otherwise
        
        # Agent stores this experience
        agent.remember(state, action, reward, next_state, done)
        
        # Update the state
        state = next_state
        
        if done:
            print(f"Episode: {e+1}/{EPISODES}, Score: {time+1}, Epsilon: {agent.epsilon:.2}")
            break
    
    # Train the agent with experience replay
    agent.replay(BATCH_SIZE)
# Out:
# Episode: 1/500, Score: 32, Epsilon: 1.0
# Episode: 2/500, Score: 5, Epsilon: 0.99
# Episode: 3/500, Score: 6, Epsilon: 0.99
# Episode: 4/500, Score: 16, Epsilon: 0.99
# Episode: 5/500, Score: 15, Epsilon: 0.98
# Episode: 6/500, Score: 22, Epsilon: 0.98
# Episode: 7/500, Score: 6, Epsilon: 0.97
# Episode: 8/500, Score: 24, Epsilon: 0.97
# Episode: 9/500, Score: 5, Epsilon: 0.96
# Episode: 10/500, Score: 7, Epsilon: 0.96
# Episode: 11/500, Score: 6, Epsilon: 0.95
# Episode: 12/500, Score: 12, Epsilon: 0.95
# Episode: 13/500, Score: 11, Epsilon: 0.94
# Episode: 14/500, Score: 18, Epsilon: 0.94
# Episode: 15/500, Score: 29, Epsilon: 0.93
# Episode: 16/500, Score: 28, Epsilon: 0.93
# Episode: 17/500, Score: 16, Epsilon: 0.92
# Episode: 18/500, Score: 9, Epsilon: 0.92
# Episode: 19/500, Score: 6, Epsilon: 0.91
# Episode: 20/500, Score: 4, Epsilon: 0.91
# Episode: 21/500, Score: 6, Epsilon: 0.9
# Episode: 22/500, Score: 40, Epsilon: 0.9
# Episode: 23/500, Score: 28, Epsilon: 0.9
# Episode: 24/500, Score: 6, Epsilon: 0.89
# Episode: 25/500, Score: 6, Epsilon: 0.89
# Episode: 26/500, Score: 32, Epsilon: 0.88
# Episode: 27/500, Score: 10, Epsilon: 0.88
# Episode: 28/500, Score: 4, Epsilon: 0.87
# Episode: 29/500, Score: 23, Epsilon: 0.87
# Episode: 30/500, Score: 14, Epsilon: 0.86
# Episode: 31/500, Score: 12, Epsilon: 0.86
# Episode: 32/500, Score: 12, Epsilon: 0.86
# Episode: 33/500, Score: 9, Epsilon: 0.85
# Episode: 34/500, Score: 7, Epsilon: 0.85
# Episode: 35/500, Score: 23, Epsilon: 0.84
# Episode: 36/500, Score: 16, Epsilon: 0.84
# Episode: 37/500, Score: 42, Epsilon: 0.83
# Episode: 38/500, Score: 19, Epsilon: 0.83
# Episode: 39/500, Score: 4, Epsilon: 0.83
# Episode: 40/500, Score: 10, Epsilon: 0.82
# Episode: 41/500, Score: 10, Epsilon: 0.82
# Episode: 42/500, Score: 13, Epsilon: 0.81
# Episode: 43/500, Score: 21, Epsilon: 0.81
# Episode: 44/500, Score: 11, Epsilon: 0.81
# Episode: 45/500, Score: 6, Epsilon: 0.8
# Episode: 46/500, Score: 9, Epsilon: 0.8
# Episode: 47/500, Score: 12, Epsilon: 0.79
# Episode: 48/500, Score: 26, Epsilon: 0.79
# Episode: 49/500, Score: 9, Epsilon: 0.79
# Episode: 50/500, Score: 15, Epsilon: 0.78
# Episode: 51/500, Score: 16, Epsilon: 0.78
# Episode: 52/500, Score: 4, Epsilon: 0.77
# Episode: 53/500, Score: 10, Epsilon: 0.77
# Episode: 54/500, Score: 6, Epsilon: 0.77
# Episode: 55/500, Score: 11, Epsilon: 0.76
# Episode: 56/500, Score: 9, Epsilon: 0.76
# Episode: 57/500, Score: 4, Epsilon: 0.76
# Episode: 58/500, Score: 9, Epsilon: 0.75
# Episode: 59/500, Score: 9, Epsilon: 0.75
# Episode: 60/500, Score: 10, Epsilon: 0.74
# Episode: 61/500, Score: 8, Epsilon: 0.74
# Episode: 62/500, Score: 6, Epsilon: 0.74
# Episode: 63/500, Score: 4, Epsilon: 0.73
# Episode: 64/500, Score: 31, Epsilon: 0.73
# Episode: 65/500, Score: 17, Epsilon: 0.73
# Episode: 66/500, Score: 13, Epsilon: 0.72
# Episode: 67/500, Score: 26, Epsilon: 0.72
# Episode: 68/500, Score: 4, Epsilon: 0.71
# Episode: 69/500, Score: 13, Epsilon: 0.71
# Episode: 70/500, Score: 15, Epsilon: 0.71
# Episode: 71/500, Score: 18, Epsilon: 0.7
# Episode: 72/500, Score: 6, Epsilon: 0.7
# Episode: 73/500, Score: 8, Epsilon: 0.7
# Episode: 74/500, Score: 8, Epsilon: 0.69
# Episode: 75/500, Score: 16, Epsilon: 0.69
# Episode: 76/500, Score: 12, Epsilon: 0.69
# Episode: 77/500, Score: 18, Epsilon: 0.68
# Episode: 78/500, Score: 8, Epsilon: 0.68
# Episode: 79/500, Score: 8, Epsilon: 0.68
# Episode: 80/500, Score: 16, Epsilon: 0.67
# Episode: 81/500, Score: 6, Epsilon: 0.67
# Episode: 82/500, Score: 5, Epsilon: 0.67
# Episode: 83/500, Score: 24, Epsilon: 0.66
# Episode: 84/500, Score: 4, Epsilon: 0.66
# Episode: 85/500, Score: 6, Epsilon: 0.66
# Episode: 86/500, Score: 6, Epsilon: 0.65
# Episode: 87/500, Score: 12, Epsilon: 0.65
# Episode: 88/500, Score: 18, Epsilon: 0.65
# Episode: 89/500, Score: 7, Epsilon: 0.64
# Episode: 90/500, Score: 7, Epsilon: 0.64
# Episode: 91/500, Score: 5, Epsilon: 0.64
# Episode: 92/500, Score: 6, Epsilon: 0.63
# Episode: 93/500, Score: 8, Epsilon: 0.63
# Episode: 94/500, Score: 6, Epsilon: 0.63
# Episode: 95/500, Score: 14, Epsilon: 0.62
# Episode: 96/500, Score: 4, Epsilon: 0.62
# Episode: 97/500, Score: 8, Epsilon: 0.62
# Episode: 98/500, Score: 10, Epsilon: 0.61
# Episode: 99/500, Score: 5, Epsilon: 0.61
# Episode: 100/500, Score: 11, Epsilon: 0.61
# Episode: 101/500, Score: 4, Epsilon: 0.61
# Episode: 102/500, Score: 7, Epsilon: 0.6
# Episode: 103/500, Score: 4, Epsilon: 0.6
# Episode: 104/500, Score: 8, Epsilon: 0.6
# Episode: 105/500, Score: 4, Epsilon: 0.59
# Episode: 106/500, Score: 19, Epsilon: 0.59
# Episode: 107/500, Score: 4, Epsilon: 0.59
# Episode: 108/500, Score: 4, Epsilon: 0.58
# Episode: 109/500, Score: 11, Epsilon: 0.58
# Episode: 110/500, Score: 7, Epsilon: 0.58
# Episode: 111/500, Score: 4, Epsilon: 0.58
# Episode: 112/500, Score: 6, Epsilon: 0.57
# Episode: 113/500, Score: 7, Epsilon: 0.57
# Episode: 114/500, Score: 5, Epsilon: 0.57
# Episode: 115/500, Score: 12, Epsilon: 0.56
# Episode: 116/500, Score: 4, Epsilon: 0.56
# Episode: 117/500, Score: 16, Epsilon: 0.56
# Episode: 118/500, Score: 9, Epsilon: 0.56
# Episode: 119/500, Score: 8, Epsilon: 0.55
# Episode: 120/500, Score: 6, Epsilon: 0.55
# Episode: 121/500, Score: 6, Epsilon: 0.55
# Episode: 122/500, Score: 6, Epsilon: 0.55
# Episode: 123/500, Score: 10, Epsilon: 0.54
# Episode: 124/500, Score: 4, Epsilon: 0.54
# Episode: 125/500, Score: 4, Epsilon: 0.54
# Episode: 126/500, Score: 13, Epsilon: 0.53
# Episode: 127/500, Score: 4, Epsilon: 0.53
# Episode: 128/500, Score: 16, Epsilon: 0.53
# Episode: 129/500, Score: 7, Epsilon: 0.53
# Episode: 130/500, Score: 6, Epsilon: 0.52
# Episode: 131/500, Score: 4, Epsilon: 0.52
# Episode: 132/500, Score: 12, Epsilon: 0.52
# Episode: 133/500, Score: 6, Epsilon: 0.52
# Episode: 134/500, Score: 6, Epsilon: 0.51
# Episode: 135/500, Score: 4, Epsilon: 0.51
# Episode: 136/500, Score: 4, Epsilon: 0.51
# Episode: 137/500, Score: 6, Epsilon: 0.51
# Episode: 138/500, Score: 15, Epsilon: 0.5
# Episode: 139/500, Score: 6, Epsilon: 0.5
# Episode: 140/500, Score: 6, Epsilon: 0.5
# Episode: 141/500, Score: 10, Epsilon: 0.5
# Episode: 142/500, Score: 7, Epsilon: 0.49
# Episode: 143/500, Score: 5, Epsilon: 0.49
# Episode: 144/500, Score: 7, Epsilon: 0.49
# Episode: 145/500, Score: 5, Epsilon: 0.49
# Episode: 146/500, Score: 4, Epsilon: 0.48
# Episode: 147/500, Score: 6, Epsilon: 0.48
# Episode: 148/500, Score: 4, Epsilon: 0.48
# Episode: 149/500, Score: 4, Epsilon: 0.48
# Episode: 150/500, Score: 8, Epsilon: 0.47
# Episode: 151/500, Score: 8, Epsilon: 0.47
# Episode: 152/500, Score: 7, Epsilon: 0.47
# Episode: 153/500, Score: 4, Epsilon: 0.47
# Episode: 154/500, Score: 4, Epsilon: 0.46
# Episode: 155/500, Score: 4, Epsilon: 0.46
# Episode: 156/500, Score: 6, Epsilon: 0.46
# Episode: 157/500, Score: 8, Epsilon: 0.46
# Episode: 158/500, Score: 4, Epsilon: 0.46
# Episode: 159/500, Score: 4, Epsilon: 0.45
# Episode: 160/500, Score: 4, Epsilon: 0.45
# Episode: 161/500, Score: 4, Epsilon: 0.45
# Episode: 162/500, Score: 6, Epsilon: 0.45
# Episode: 163/500, Score: 4, Epsilon: 0.44
# Episode: 164/500, Score: 10, Epsilon: 0.44
# Episode: 165/500, Score: 6, Epsilon: 0.44
# Episode: 166/500, Score: 4, Epsilon: 0.44
# Episode: 167/500, Score: 4, Epsilon: 0.44
# Episode: 168/500, Score: 6, Epsilon: 0.43
# Episode: 169/500, Score: 7, Epsilon: 0.43
# Episode: 170/500, Score: 7, Epsilon: 0.43
# Episode: 171/500, Score: 4, Epsilon: 0.43
# Episode: 172/500, Score: 4, Epsilon: 0.42
# Episode: 173/500, Score: 7, Epsilon: 0.42
# Episode: 174/500, Score: 9, Epsilon: 0.42
# Episode: 175/500, Score: 6, Epsilon: 0.42
# Episode: 176/500, Score: 6, Epsilon: 0.42
# Episode: 177/500, Score: 9, Epsilon: 0.41
# Episode: 178/500, Score: 5, Epsilon: 0.41
# Episode: 179/500, Score: 7, Epsilon: 0.41
# Episode: 180/500, Score: 4, Epsilon: 0.41
# Episode: 181/500, Score: 4, Epsilon: 0.41
# Episode: 182/500, Score: 8, Epsilon: 0.4
# Episode: 183/500, Score: 10, Epsilon: 0.4
# Episode: 184/500, Score: 4, Epsilon: 0.4
# Episode: 185/500, Score: 6, Epsilon: 0.4
# Episode: 186/500, Score: 16, Epsilon: 0.4
# Episode: 189/500, Score: 42, Epsilon: 0.39
# Episode: 190/500, Score: 4, Epsilon: 0.39
# Episode: 191/500, Score: 8, Epsilon: 0.39
# Episode: 192/500, Score: 6, Epsilon: 0.38
# Episode: 193/500, Score: 4, Epsilon: 0.38
# Episode: 194/500, Score: 5, Epsilon: 0.38
# Episode: 195/500, Score: 4, Epsilon: 0.38
# Episode: 196/500, Score: 4, Epsilon: 0.38
# Episode: 197/500, Score: 4, Epsilon: 0.37
# Episode: 198/500, Score: 4, Epsilon: 0.37
# Episode: 199/500, Score: 4, Epsilon: 0.37
# Episode: 200/500, Score: 4, Epsilon: 0.37
# Episode: 201/500, Score: 6, Epsilon: 0.37
# Episode: 202/500, Score: 5, Epsilon: 0.37
# Episode: 203/500, Score: 4, Epsilon: 0.36
# Episode: 204/500, Score: 7, Epsilon: 0.36
# Episode: 205/500, Score: 5, Epsilon: 0.36
# Episode: 206/500, Score: 4, Epsilon: 0.36
# Episode: 207/500, Score: 4, Epsilon: 0.36
# Episode: 208/500, Score: 4, Epsilon: 0.35
# Episode: 209/500, Score: 4, Epsilon: 0.35
# Episode: 210/500, Score: 7, Epsilon: 0.35
# Episode: 211/500, Score: 4, Epsilon: 0.35
# Episode: 212/500, Score: 4, Epsilon: 0.35
# Episode: 213/500, Score: 4, Epsilon: 0.35
# Episode: 214/500, Score: 4, Epsilon: 0.34
# Episode: 215/500, Score: 4, Epsilon: 0.34
# Episode: 216/500, Score: 4, Epsilon: 0.34
# Episode: 217/500, Score: 6, Epsilon: 0.34
# Episode: 218/500, Score: 9, Epsilon: 0.34
# Episode: 219/500, Score: 6, Epsilon: 0.34
# Episode: 220/500, Score: 4, Epsilon: 0.33
# Episode: 221/500, Score: 9, Epsilon: 0.33
# Episode: 222/500, Score: 4, Epsilon: 0.33
# Episode: 223/500, Score: 4, Epsilon: 0.33
# Episode: 224/500, Score: 7, Epsilon: 0.33
# Episode: 225/500, Score: 4, Epsilon: 0.33
# Episode: 226/500, Score: 4, Epsilon: 0.32
# Episode: 227/500, Score: 4, Epsilon: 0.32
# Episode: 228/500, Score: 5, Epsilon: 0.32
# Episode: 229/500, Score: 4, Epsilon: 0.32
# Episode: 230/500, Score: 8, Epsilon: 0.32
# Episode: 231/500, Score: 4, Epsilon: 0.32
# Episode: 232/500, Score: 4, Epsilon: 0.31
# Episode: 233/500, Score: 4, Epsilon: 0.31
# Episode: 234/500, Score: 4, Epsilon: 0.31
# Episode: 235/500, Score: 4, Epsilon: 0.31
# Episode: 236/500, Score: 4, Epsilon: 0.31
# Episode: 237/500, Score: 8, Epsilon: 0.31
# Episode: 238/500, Score: 4, Epsilon: 0.3
# Episode: 239/500, Score: 4, Epsilon: 0.3
# Episode: 240/500, Score: 4, Epsilon: 0.3
# Episode: 241/500, Score: 4, Epsilon: 0.3
# Episode: 242/500, Score: 6, Epsilon: 0.3
# Episode: 243/500, Score: 4, Epsilon: 0.3
# Episode: 244/500, Score: 4, Epsilon: 0.3
# Episode: 245/500, Score: 4, Epsilon: 0.29
# Episode: 246/500, Score: 8, Epsilon: 0.29
# Episode: 247/500, Score: 6, Epsilon: 0.29
# Episode: 248/500, Score: 4, Epsilon: 0.29
# Episode: 249/500, Score: 4, Epsilon: 0.29
# Episode: 250/500, Score: 6, Epsilon: 0.29
# Episode: 251/500, Score: 5, Epsilon: 0.29
# Episode: 252/500, Score: 4, Epsilon: 0.28
# Episode: 253/500, Score: 4, Epsilon: 0.28
# Episode: 254/500, Score: 4, Epsilon: 0.28
# Episode: 255/500, Score: 7, Epsilon: 0.28
# Episode: 256/500, Score: 4, Epsilon: 0.28
# Episode: 257/500, Score: 4, Epsilon: 0.28
# Episode: 258/500, Score: 4, Epsilon: 0.28
# Episode: 259/500, Score: 6, Epsilon: 0.27
# Episode: 260/500, Score: 4, Epsilon: 0.27
# Episode: 261/500, Score: 12, Epsilon: 0.27
# Episode: 262/500, Score: 4, Epsilon: 0.27
# Episode: 263/500, Score: 4, Epsilon: 0.27
# Episode: 264/500, Score: 4, Epsilon: 0.27
# Episode: 265/500, Score: 4, Epsilon: 0.27
# Episode: 266/500, Score: 4, Epsilon: 0.26
# Episode: 267/500, Score: 6, Epsilon: 0.26
# Episode: 268/500, Score: 4, Epsilon: 0.26
# Episode: 269/500, Score: 6, Epsilon: 0.26
# Episode: 270/500, Score: 6, Epsilon: 0.26
# Episode: 271/500, Score: 6, Epsilon: 0.26
# Episode: 272/500, Score: 4, Epsilon: 0.26
# Episode: 273/500, Score: 4, Epsilon: 0.26
# Episode: 274/500, Score: 4, Epsilon: 0.25
# Episode: 275/500, Score: 4, Epsilon: 0.25
# Episode: 276/500, Score: 10, Epsilon: 0.25
# Episode: 277/500, Score: 4, Epsilon: 0.25
# Episode: 278/500, Score: 6, Epsilon: 0.25
# Episode: 279/500, Score: 4, Epsilon: 0.25
# Episode: 280/500, Score: 4, Epsilon: 0.25
# Episode: 281/500, Score: 8, Epsilon: 0.25
# Episode: 282/500, Score: 5, Epsilon: 0.24
# Episode: 283/500, Score: 4, Epsilon: 0.24
# Episode: 284/500, Score: 4, Epsilon: 0.24
# Episode: 285/500, Score: 6, Epsilon: 0.24
# Episode: 286/500, Score: 10, Epsilon: 0.24
# Episode: 287/500, Score: 10, Epsilon: 0.24
# Episode: 288/500, Score: 5, Epsilon: 0.24
# Episode: 289/500, Score: 5, Epsilon: 0.24
# Episode: 290/500, Score: 4, Epsilon: 0.23
# Episode: 291/500, Score: 6, Epsilon: 0.23
# Episode: 292/500, Score: 4, Epsilon: 0.23
# Episode: 293/500, Score: 4, Epsilon: 0.23
# Episode: 294/500, Score: 5, Epsilon: 0.23
# Episode: 295/500, Score: 6, Epsilon: 0.23
# Episode: 296/500, Score: 4, Epsilon: 0.23
# Episode: 297/500, Score: 4, Epsilon: 0.23
# Episode: 298/500, Score: 4, Epsilon: 0.23
# Episode: 299/500, Score: 4, Epsilon: 0.22
# Episode: 300/500, Score: 4, Epsilon: 0.22
# Episode: 301/500, Score: 4, Epsilon: 0.22
# Episode: 302/500, Score: 4, Epsilon: 0.22
# Episode: 303/500, Score: 6, Epsilon: 0.22
# Episode: 304/500, Score: 4, Epsilon: 0.22
# Episode: 305/500, Score: 6, Epsilon: 0.22
# Episode: 306/500, Score: 4, Epsilon: 0.22
# Episode: 307/500, Score: 4, Epsilon: 0.22
# Episode: 308/500, Score: 8, Epsilon: 0.21
# Episode: 309/500, Score: 4, Epsilon: 0.21
# Episode: 310/500, Score: 4, Epsilon: 0.21
# Episode: 311/500, Score: 4, Epsilon: 0.21
# Episode: 312/500, Score: 4, Epsilon: 0.21
# Episode: 313/500, Score: 4, Epsilon: 0.21
# Episode: 314/500, Score: 4, Epsilon: 0.21
# Episode: 315/500, Score: 4, Epsilon: 0.21
# Episode: 316/500, Score: 4, Epsilon: 0.21
# Episode: 317/500, Score: 6, Epsilon: 0.21
# Episode: 318/500, Score: 4, Epsilon: 0.2
# Episode: 319/500, Score: 4, Epsilon: 0.2
# Episode: 320/500, Score: 4, Epsilon: 0.2
# Episode: 321/500, Score: 4, Epsilon: 0.2
# Episode: 322/500, Score: 4, Epsilon: 0.2
# Episode: 323/500, Score: 8, Epsilon: 0.2
# Episode: 324/500, Score: 4, Epsilon: 0.2
# Episode: 325/500, Score: 4, Epsilon: 0.2
# Episode: 326/500, Score: 6, Epsilon: 0.2
# Episode: 327/500, Score: 4, Epsilon: 0.2
# Episode: 328/500, Score: 4, Epsilon: 0.19
# Episode: 329/500, Score: 4, Epsilon: 0.19
# Episode: 330/500, Score: 4, Epsilon: 0.19
# Episode: 331/500, Score: 4, Epsilon: 0.19
# Episode: 332/500, Score: 4, Epsilon: 0.19
# Episode: 333/500, Score: 4, Epsilon: 0.19
# Episode: 334/500, Score: 4, Epsilon: 0.19
# Episode: 335/500, Score: 4, Epsilon: 0.19
# Episode: 336/500, Score: 4, Epsilon: 0.19
# Episode: 337/500, Score: 6, Epsilon: 0.19
# Episode: 338/500, Score: 4, Epsilon: 0.18
# Episode: 339/500, Score: 4, Epsilon: 0.18
# Episode: 340/500, Score: 4, Epsilon: 0.18
# Episode: 341/500, Score: 4, Epsilon: 0.18
# Episode: 342/500, Score: 4, Epsilon: 0.18
# Episode: 343/500, Score: 4, Epsilon: 0.18
# Episode: 344/500, Score: 4, Epsilon: 0.18
# Episode: 345/500, Score: 4, Epsilon: 0.18
# Episode: 346/500, Score: 4, Epsilon: 0.18
# Episode: 347/500, Score: 6, Epsilon: 0.18
# Episode: 348/500, Score: 4, Epsilon: 0.18
# Episode: 349/500, Score: 4, Epsilon: 0.17
# Episode: 350/500, Score: 5, Epsilon: 0.17
# Episode: 351/500, Score: 6, Epsilon: 0.17
# Episode: 352/500, Score: 4, Epsilon: 0.17
# Episode: 353/500, Score: 9, Epsilon: 0.17
# Episode: 354/500, Score: 4, Epsilon: 0.17
# Episode: 355/500, Score: 4, Epsilon: 0.17
# Episode: 356/500, Score: 4, Epsilon: 0.17
# Episode: 357/500, Score: 4, Epsilon: 0.17
# Episode: 358/500, Score: 4, Epsilon: 0.17
# Episode: 359/500, Score: 6, Epsilon: 0.17
# Episode: 360/500, Score: 4, Epsilon: 0.17
# Episode: 361/500, Score: 4, Epsilon: 0.16
# Episode: 362/500, Score: 6, Epsilon: 0.16
# Episode: 363/500, Score: 4, Epsilon: 0.16
# Episode: 364/500, Score: 4, Epsilon: 0.16
# Episode: 365/500, Score: 4, Epsilon: 0.16
# Episode: 366/500, Score: 4, Epsilon: 0.16
# Episode: 367/500, Score: 6, Epsilon: 0.16
# Episode: 368/500, Score: 4, Epsilon: 0.16
# Episode: 369/500, Score: 4, Epsilon: 0.16
# Episode: 370/500, Score: 4, Epsilon: 0.16
# Episode: 371/500, Score: 4, Epsilon: 0.16
# Episode: 372/500, Score: 4, Epsilon: 0.16
# Episode: 373/500, Score: 4, Epsilon: 0.15
# Episode: 374/500, Score: 4, Epsilon: 0.15
# Episode: 375/500, Score: 4, Epsilon: 0.15
# Episode: 376/500, Score: 4, Epsilon: 0.15
# Episode: 377/500, Score: 4, Epsilon: 0.15
# Episode: 378/500, Score: 6, Epsilon: 0.15
# Episode: 379/500, Score: 6, Epsilon: 0.15
# Episode: 380/500, Score: 8, Epsilon: 0.15
# Episode: 381/500, Score: 6, Epsilon: 0.15
# Episode: 382/500, Score: 4, Epsilon: 0.15
# Episode: 383/500, Score: 7, Epsilon: 0.15
# Episode: 384/500, Score: 6, Epsilon: 0.15
# Episode: 385/500, Score: 4, Epsilon: 0.15
# Episode: 386/500, Score: 4, Epsilon: 0.15
# Episode: 387/500, Score: 4, Epsilon: 0.14
# Episode: 388/500, Score: 4, Epsilon: 0.14
# Episode: 389/500, Score: 4, Epsilon: 0.14
# Episode: 390/500, Score: 6, Epsilon: 0.14
# Episode: 391/500, Score: 6, Epsilon: 0.14
# Episode: 392/500, Score: 4, Epsilon: 0.14
# Episode: 393/500, Score: 4, Epsilon: 0.14
# Episode: 394/500, Score: 4, Epsilon: 0.14
# Episode: 395/500, Score: 6, Epsilon: 0.14
# Episode: 396/500, Score: 4, Epsilon: 0.14
# Episode: 397/500, Score: 8, Epsilon: 0.14
# Episode: 398/500, Score: 4, Epsilon: 0.14
# Episode: 399/500, Score: 4, Epsilon: 0.14
# Episode: 400/500, Score: 6, Epsilon: 0.14
# Episode: 401/500, Score: 4, Epsilon: 0.13
# Episode: 402/500, Score: 6, Epsilon: 0.13
# Episode: 403/500, Score: 4, Epsilon: 0.13
# Episode: 404/500, Score: 6, Epsilon: 0.13
# Episode: 405/500, Score: 4, Epsilon: 0.13
# Episode: 406/500, Score: 4, Epsilon: 0.13
# Episode: 407/500, Score: 4, Epsilon: 0.13
# Episode: 408/500, Score: 4, Epsilon: 0.13
# Episode: 409/500, Score: 4, Epsilon: 0.13
# Episode: 410/500, Score: 6, Epsilon: 0.13
# Episode: 411/500, Score: 6, Epsilon: 0.13
# Episode: 412/500, Score: 4, Epsilon: 0.13
# Episode: 413/500, Score: 4, Epsilon: 0.13
# Episode: 414/500, Score: 4, Epsilon: 0.13
# Episode: 415/500, Score: 6, Epsilon: 0.13
# Episode: 416/500, Score: 4, Epsilon: 0.12
# Episode: 417/500, Score: 4, Epsilon: 0.12
# Episode: 418/500, Score: 4, Epsilon: 0.12
# Episode: 419/500, Score: 4, Epsilon: 0.12
# Episode: 420/500, Score: 4, Epsilon: 0.12
# Episode: 421/500, Score: 4, Epsilon: 0.12
# Episode: 422/500, Score: 4, Epsilon: 0.12
# Episode: 423/500, Score: 6, Epsilon: 0.12
# Episode: 424/500, Score: 4, Epsilon: 0.12
# Episode: 425/500, Score: 4, Epsilon: 0.12
# Episode: 426/500, Score: 4, Epsilon: 0.12
# Episode: 427/500, Score: 6, Epsilon: 0.12
# Episode: 428/500, Score: 4, Epsilon: 0.12
# Episode: 429/500, Score: 4, Epsilon: 0.12
# Episode: 430/500, Score: 6, Epsilon: 0.12
# Episode: 431/500, Score: 4, Epsilon: 0.12
# Episode: 432/500, Score: 4, Epsilon: 0.12
# Episode: 433/500, Score: 4, Epsilon: 0.11
# Episode: 434/500, Score: 4, Epsilon: 0.11
# Episode: 435/500, Score: 4, Epsilon: 0.11
# Episode: 436/500, Score: 4, Epsilon: 0.11
# Episode: 437/500, Score: 4, Epsilon: 0.11
# Episode: 438/500, Score: 6, Epsilon: 0.11
# Episode: 439/500, Score: 4, Epsilon: 0.11
# Episode: 440/500, Score: 4, Epsilon: 0.11
# Episode: 441/500, Score: 4, Epsilon: 0.11
# Episode: 442/500, Score: 4, Epsilon: 0.11
# Episode: 443/500, Score: 4, Epsilon: 0.11
# Episode: 444/500, Score: 4, Epsilon: 0.11
# Episode: 445/500, Score: 4, Epsilon: 0.11
# Episode: 446/500, Score: 5, Epsilon: 0.11
# Episode: 447/500, Score: 4, Epsilon: 0.11
# Episode: 448/500, Score: 4, Epsilon: 0.11
# Episode: 449/500, Score: 4, Epsilon: 0.11
# Episode: 450/500, Score: 4, Epsilon: 0.11
# Episode: 451/500, Score: 6, Epsilon: 0.1
# Episode: 452/500, Score: 4, Epsilon: 0.1
# Episode: 453/500, Score: 4, Epsilon: 0.1
# Episode: 454/500, Score: 4, Epsilon: 0.1
# Episode: 455/500, Score: 4, Epsilon: 0.1
# Episode: 456/500, Score: 4, Epsilon: 0.1
# Episode: 457/500, Score: 4, Epsilon: 0.1
# Episode: 458/500, Score: 4, Epsilon: 0.1
# Episode: 459/500, Score: 4, Epsilon: 0.1
# Episode: 460/500, Score: 4, Epsilon: 0.1
# Episode: 461/500, Score: 4, Epsilon: 0.1
# Episode: 462/500, Score: 4, Epsilon: 0.099
# Episode: 463/500, Score: 4, Epsilon: 0.099
# Episode: 464/500, Score: 4, Epsilon: 0.098
# Episode: 465/500, Score: 4, Epsilon: 0.098
# Episode: 466/500, Score: 4, Epsilon: 0.097
# Episode: 467/500, Score: 4, Epsilon: 0.097
# Episode: 468/500, Score: 4, Epsilon: 0.096
# Episode: 469/500, Score: 4, Epsilon: 0.096
# Episode: 470/500, Score: 4, Epsilon: 0.095
# Episode: 471/500, Score: 4, Epsilon: 0.095
# Episode: 472/500, Score: 6, Epsilon: 0.094
# Episode: 473/500, Score: 4, Epsilon: 0.094
# Episode: 474/500, Score: 4, Epsilon: 0.093
# Episode: 475/500, Score: 11, Epsilon: 0.093
# Episode: 476/500, Score: 4, Epsilon: 0.092
# Episode: 477/500, Score: 6, Epsilon: 0.092
# Episode: 478/500, Score: 4, Epsilon: 0.092
# Episode: 479/500, Score: 4, Epsilon: 0.091
# Episode: 480/500, Score: 4, Epsilon: 0.091
# Episode: 481/500, Score: 4, Epsilon: 0.09
# Episode: 482/500, Score: 6, Epsilon: 0.09
# Episode: 483/500, Score: 4, Epsilon: 0.089
# Episode: 484/500, Score: 4, Epsilon: 0.089
# Episode: 485/500, Score: 4, Epsilon: 0.088
# Episode: 486/500, Score: 4, Epsilon: 0.088
# Episode: 487/500, Score: 4, Epsilon: 0.088
# Episode: 488/500, Score: 4, Epsilon: 0.087
# Episode: 489/500, Score: 4, Epsilon: 0.087
# Episode: 490/500, Score: 4, Epsilon: 0.086
# Episode: 491/500, Score: 6, Epsilon: 0.086
# Episode: 492/500, Score: 4, Epsilon: 0.085
# Episode: 493/500, Score: 4, Epsilon: 0.085
# Episode: 494/500, Score: 6, Epsilon: 0.084
# Episode: 495/500, Score: 4, Epsilon: 0.084
# Episode: 496/500, Score: 4, Epsilon: 0.084
# Episode: 497/500, Score: 4, Epsilon: 0.083
# Episode: 498/500, Score: 4, Epsilon: 0.083
# Episode: 499/500, Score: 4, Epsilon: 0.082
# Episode: 500/500, Score: 4, Epsilon: 0.082
